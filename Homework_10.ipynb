# %% [markdown]
# <a href="https://colab.research.google.com/github/eugenepro777/GB_repos_21.10/blob/main/Homework_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задача №65.
# Написать EDA для датасета про пингвинов
# Необходимо:
#
# ● Использовать 2-3 точечных графика
#
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
#
# ● Использовать PairGrid с типом графика на ваш выбор
# ● Изобразить Heatmap
#
# ● Использовать 2-3 гистограммы
#
# -----------------
# ***Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным скриптом:***
#
# ----
# *penguins = sns.load_dataset("penguins")*
#
# *penguins.head()*

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **Выведем типы данных, использующихся для описания наших пингвинов**

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.scatterplot(data=penguins, x="island", y="species", hue="bill_depth_mm", style=7,  size=10)
# Out:
# <AxesSubplot:xlabel='island', ylabel='species'>

# %%
sns.scatterplot(data=penguins, x="species", y="island", hue="flipper_length_mm", style=6,  size=30)
# Out:
# <AxesSubplot:xlabel='species', ylabel='island'>

# %%
sns.scatterplot(data=penguins, x="island", y="body_mass_g", hue="sex", size=50)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x="bill_length_mm", y="body_mass_g")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_depth_mm", hue="body_mass_g", size=50)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# **PairGrid для наших пингвинов, сразу строим разные точечные графики для параметров 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'**

# %%
cols = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
g = sns.PairGrid(penguins[cols])
g.map(sns.scatterplot)

# %% [markdown]
# **Для начала работы с тепловыми картами HeatMap создаём базовую корреляционную матрицу нашего фрейма - penguins**

# %%
sns.heatmap(penguins.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Используем аргумент для аннотации, присвоив значение True**

# %%
sns.heatmap(penguins.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Округляем значения в нашей тепловой карте с помощью параметра fmt='.1g'**

# %%
sns.heatmap(penguins.corr(), annot = True, fmt='.1g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Регулировка осей (измерения), теперь у нас оси от -1 до 1, с центром в 0**

# %%
sns.heatmap(penguins.corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Добавим красоты - используем другой набор цветов для нашей HeatMap**

# %%
sns.heatmap(penguins.corr(), annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Добавим обводку наших ячеек черными линиями с толщиной 5**

# %%
sns.heatmap(penguins.corr(), annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=5, linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Построим гистограмму для длины плавника**

# %%
sns.histplot(data=penguins, x = 'flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# **И для веса пингивина, причем отсортируем упитанных пингвинов. Видим что упитанных самцов больше**

# %%
sns.histplot(data=penguins[penguins['body_mass_g'] > 5000], x="sex")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %% [markdown]
# **Посмотрим где больше всех обитает упитанных особей**

# %%
sns.histplot(data=penguins[penguins['body_mass_g'] > 5000], x="island", hue="sex")
# Out:
# <AxesSubplot:xlabel='island', ylabel='Count'>

# %% [markdown]
# **На острове Biscoe живут самые счастливые (упитанные) пингвины, причем самцы превалируют, их больше чем в 5 раз.**

# %% [markdown]
# # Задача №67.
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %% [markdown]
# **Создаём новый столбец height_group в таблице, отвечающий за длину клюва**

# %%
penguins.loc[penguins['bill_length_mm'] <= 35, 'height_group'] = 'low'
penguins.loc[(penguins['bill_length_mm'] > 35) & (penguins['bill_length_mm'] <= 42), 'height_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] > 42, 'height_group'] = 'high'

# %% [markdown]
# **Отобразим созданный столбец и его "голову"**

# %%
penguins['height_group']
# Out:
# 0      middle
# 1      middle
# 2      middle
# 3         NaN
# 4      middle
#         ...
# 339       NaN
# 340      high
# 341      high
# 342      high
# 343      high
# Name: height_group, Length: 344, dtype: object

# %%
penguins['height_group'].head(20)
# Out:
# 0     middle
# 1     middle
# 2     middle
# 3        NaN
# 4     middle
# 5     middle
# 6     middle
# 7     middle
# 8        low
# 9     middle
# 10    middle
# 11    middle
# 12    middle
# 13    middle
# 14       low
# 15    middle
# 16    middle
# 17      high
# 18       low
# 19      high
# Name: height_group, dtype: object

# %% [markdown]
# **Вычислим среднее значение среди каждой из трех групп пингвинов, отсортированных по длине клюва**

# %%
penguins.groupby('height_group')['bill_length_mm'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='height_group'>

# %% [markdown]
# # Задача №69.
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
sns.histplot(data=penguins, x = 'flipper_length_mm', hue='height_group')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ***Видим что среди пингвинов с длиной плавника от 172 и до 195 мм, преобладают пингвины со средней длиной клюва, с длиной плавников больше 195 мм преобладают пингвины с длинными клювами.
# Пингвинов с короткими клювами меньше всего и короткие клювы есть только у пингвинов с длиной плавников в районе 180 - 200 мм.***

# %% [markdown]
# # Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?
#
# ---------------------------
# import random
#
# lst = ['robot'] * 10
#
# lst += ['human'] * 10
#
# random.shuffle(lst)
#
# data = pd.DataFrame({'whoAmI':lst})
#
# data.head()

# %%
import random

# %%
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  human
# 4  robot

# %%
data
# Out:
#    whoAmI
# 0   human
# 1   human
# 2   robot
# 3   human
# 4   robot
# 5   robot
# 6   human
# 7   robot
# 8   human
# 9   robot
# 10  robot
# 11  robot
# 12  human
# 13  human
# 14  human
# 15  human
# 16  robot
# 17  human
# 18  robot
# 19  robot

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0       0      1
# 1       1      0
# 2       1      0
# 3       0      1
# 4       1      0
# 5       0      1
# 6       1      0
# 7       1      0
# 8       0      1
# 9       1      0
# 10      0      1
# 11      0      1
# 12      1      0
# 13      0      1
# 14      0      1
# 15      1      0
# 16      1      0
# 17      1      0
# 18      0      1
# 19      0      1
